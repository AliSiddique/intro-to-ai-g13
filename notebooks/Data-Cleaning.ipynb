# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../spotify_data.csv')
df
# Out:
#          Unnamed: 0      artist_name                         track_name  \
# 0                 0       Jason Mraz                    I Won't Give Up
# 1                 1       Jason Mraz                   93 Million Miles
# 2                 2    Joshua Hyslop                   Do Not Let Me Go
# 3                 3     Boyce Avenue                           Fast Car
# 4                 4     Andrew Belle                   Sky's Still Blue
# ...             ...              ...                                ...
# 1159759     1473391     Nicola Conte                      Black Spirits
# 1159760     1473392     Nicola Conte                         Quiet Dawn
# 1159761     1473393       Amon Tobin                  Morning Ms Candis
# 1159762     1473394  Peace Orchestra      Happy Christmas (War Is Over)
# 1159763     1473395     Mo' Horizons  Hit the Road Jack (Pé Na Éstrada)
#
#                        track_id  popularity  year     genre  danceability  \
# ...

# %%
df.head()
# Out:
#     0              1                 2                       3           4   \
# 0  NaN    artist_name        track_name                track_id  popularity
# 1  0.0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6          68
# 2  1.0     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218          50
# 3  2.0  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F          57
# 4  3.0   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz          58
#
#      5         6             7       8    9         10    11           12  \
# 0  year     genre  danceability  energy  key  loudness  mode  speechiness
# 1  2012  acoustic         0.483   0.303    4   -10.058     1       0.0429
# 2  2012  acoustic         0.572   0.454    3   -10.286     1       0.0258
# 3  2012  acoustic         0.409   0.234    3   -13.711     1       0.0323
# 4  2012  acoustic         0.392   0.251   10    -9.845     1       0.0363
#
# ...

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
