# %% [markdown]
# # Data analysis for Group 13

# %% [markdown]
# ## Packages used: matplotlib, pandas and numpy

# %% [markdown]
# ### Documentation used for graphs and functions
# - [Somepandasfunctions](https://www.w3schools.com/python/pandas/default.asp) - Some pandas functions used
# - [Numpy](https://numpy.org/doc/stable/reference/index.html) - Numpy function references
# - [PandsDocs](https://pandas.pydata.org/docs/reference/index.html) - Pandas documentation

# %%
# %pip install numpy pandas matplotlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Load the csv

# %%
# Loading the csv into pandas and displaying the first 5 rows
df = pd.read_csv("../spotify_data.csv")
df.head()
# Out:
#    Unnamed: 0    artist_name        track_name                track_id  \
# 0           0     Jason Mraz   I Won't Give Up  53QF56cjZA9RTuuMZDrSA6
# 1           1     Jason Mraz  93 Million Miles  1s8tP3jP4GZcyHDsjvw218
# 2           2  Joshua Hyslop  Do Not Let Me Go  7BRCa8MPiyuvr2VU3O9W0F
# 3           3   Boyce Avenue          Fast Car  63wsZUhUZLlh1OsyrZq7sz
# 4           4   Andrew Belle  Sky's Still Blue  6nXIYClvJAfi6ujLiKqEq8
#
#    popularity  year     genre  danceability  energy  key  loudness  mode  \
# 0          68  2012  acoustic         0.483   0.303    4   -10.058     1
# 1          50  2012  acoustic         0.572   0.454    3   -10.286     1
# 2          57  2012  acoustic         0.409   0.234    3   -13.711     1
# 3          58  2012  acoustic         0.392   0.251   10    -9.845     1
# 4          54  2012  acoustic         0.430   0.791    6    -5.419     0
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %% [markdown]
# # Amount rows in the dataset

# %%
# Displaying the amount of rows
num_rows = len(df)
num_rows
# Out:
# 1159764

# %% [markdown]
# # Show the columns in the dataframe

# %%
# Columns in the dataframe
df.columns
# Out:
# Index(['Unnamed: 0', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'year', 'genre', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'duration_ms', 'time_signature'],
#       dtype='object')

# %% [markdown]
# # Learn about the dataset using the info method
# - [Info](https://www.w3schools.com/python/pandas/ref_df_info.asp#:~:text=The%20info()%20method%20prints,method%20actually%20prints%20the%20info.) - Info method reference

# %%
# Displaying the datasets information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1159764 entries, 0 to 1159763
# Data columns (total 20 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   Unnamed: 0        1159764 non-null  int64
#  1   artist_name       1159764 non-null  object
#  2   track_name        1159764 non-null  object
#  3   track_id          1159764 non-null  object
#  4   popularity        1159764 non-null  int64
#  5   year              1159764 non-null  int64
#  6   genre             1159764 non-null  object
#  7   danceability      1159764 non-null  float64
#  8   energy            1159764 non-null  float64
#  9   key               1159764 non-null  int64
#  10  loudness          1159764 non-null  float64
#  11  mode              1159764 non-null  int64
#  12  speechiness       1159764 non-null  float64
#  13  acousticness      1159764 non-null  float64
#  14  instrumentalness  1159764 non-null  float64
# ...

# %% [markdown]
# # Show the count, mean, median etc of the dataset
# - [PandasMethod](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html) - Describe method reference

# %%
# Describe the dataset
df.describe()
# Out:
#          Unnamed: 0    popularity          year  danceability        energy  \
# count  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# mean   6.590613e+05  1.838312e+01  2.011955e+03  5.374382e-01  6.396699e-01
# std    4.285492e+05  1.588554e+01  6.803901e+00  1.844780e-01  2.705009e-01
# min    0.000000e+00  0.000000e+00  2.000000e+03  0.000000e+00  0.000000e+00
# 25%    2.899408e+05  5.000000e+00  2.006000e+03  4.130000e-01  4.540000e-01
# 50%    5.798815e+05  1.500000e+01  2.012000e+03  5.500000e-01  6.940000e-01
# 75%    1.031689e+06  2.900000e+01  2.018000e+03  6.770000e-01  8.730000e-01
# max    1.473395e+06  1.000000e+02  2.023000e+03  9.930000e-01  1.000000e+00
#
#                 key      loudness          mode   speechiness  acousticness  \
# count  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06  1.159764e+06
# mean   5.287778e+00 -8.981353e+00  6.346533e-01  9.281477e-02  3.215370e-01
# ...

# %% [markdown]
# # Show distribution of each feature
# ## Histograms for the numeric columns in the dataset and arranges them in a grid of subplots.
# - [Histograms](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html) - Histograms references

# %%
# Get the numeric columns from the DataFrame
numeric_columns = df.select_dtypes(include=['number'])

# Define the number of bins for histograms
num_bins = 10

# Create subplots with rows and columns
num_columns = len(numeric_columns.columns)
num_rows = (num_columns + 1) // 2 
fig, axes = plt.subplots(num_rows, 2, figsize=(15, 4 * num_rows))  
fig.tight_layout(pad=2.0)  # Add padding

# lOOP through numeric columns and create histograms
for i, col in enumerate(numeric_columns.columns):
    row_index = i // 2
    col_index = i % 2
    ax = axes[row_index, col_index]

    # Create a histogram for the current column
    df[col].plot(kind='hist', ax=ax, bins=num_bins, color='skyblue')
    ax.set_title(f'Histogram of {col}')
    ax.set_xlabel(col)
    ax.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# # Links for heatmap
# ## Visualise how closely related all the features are to each other
# - [Heatmap](https://www.example.com) - Resource used to make the heatmap
# - [Correlationinnp](https://realpython.com/numpy-scipy-pandas-correlation-python/) - Used to find the correlation matrix
# ##### Danceability feature looks promising

# %%
# This line of code selects columns with numeric data types from a dataset
numeric_data = df.select_dtypes(include=[np.number])  

# Calculates the correlation matrix
correlation_matrix = np.corrcoef(numeric_data.values, rowvar=False)

# Create a new plot with a 10x8 size
plt.figure(figsize=(10, 8))

# Display the correlation matrix as an image 
plt.imshow(correlation_matrix, cmap='viridis', interpolation='nearest')

# Add a colorbar to the plot with a label to show range of values
plt.colorbar(label='Correlation')

# Set the title of the heatmap.
plt.title('Heatmap of Column Similarities')

# Set the x axis ticks with labels from the column names of numeric_data and rotate them so we can see the labels more clearly
plt.xticks(np.arange(len(numeric_data.columns)), numeric_data.columns, rotation=90)

# Set the y axis ticks with labels from the column names of numeric_data
plt.yticks(np.arange(len(numeric_data.columns)), numeric_data.columns)
# Automatically adjust the subplot parameters to ensure the plot fits within the dimensions
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find the amount of songs per year

# %%
# Get the year and the amounts
year_counts = df['year'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
plt.bar(year_counts.index, year_counts.values, color='salmon')
plt.title('Number of Songs per Year')
plt.xlabel('Year')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Find the 10 most popular genres

# %%
# Identify the most popular genres
top_genre_counts = df['genre'].value_counts().nlargest(10)  # 10 largest 
top_genres = top_genre_counts.index
top_genre_counts_values = top_genre_counts.values

# Create a bar chart for the top genres
plt.figure(figsize=(12, 6))
plt.bar(top_genres, top_genre_counts_values, color='skyblue')
plt.title('Top 10 Most Popular Genres')
plt.xlabel('Genre')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Find the 10 most popular songs

# %%
# Identify the most popular songs
top_songs = df.nlargest(10, 'popularity')  # Top 10

# Create a bar chart for the top songs
plt.figure(figsize=(12, 6))
plt.bar(top_songs['track_name'], top_songs['popularity'], color='salmon')
plt.title('Top 10 Most Popular Songs')
plt.xlabel('Song Name')
plt.ylabel('Popularity')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Get the top 10 most popular artists

# %%
# Identify the most popular artists
top_artist_counts = df['artist_name'].value_counts().nlargest(10)  # Top 10
top_artists = top_artist_counts.index
top_artist_counts_values = top_artist_counts.values

# Create a bar chart for the top artists
plt.figure(figsize=(12, 6))
plt.bar(top_artists, top_artist_counts_values, color='lightgreen')
plt.title('Top 10 Most Popular Artists')
plt.xlabel('Artist')
plt.ylabel('Number of Songs')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Show the number of songs released per year

# %%
# Group songs by year and count the number of songs per year
yearly_song_count = df.groupby('year')['track_id'].count()

# Create a line graph for the number of songs released each year
plt.figure(figsize=(12, 6))
plt.plot(yearly_song_count.index, yearly_song_count.values, marker='o', color='green')
plt.title('Number of Songs Released per Year')
plt.xlabel('Year')
plt.ylabel('Number of Songs')
plt.grid(True)
plt.show()

# %% [markdown]
# # Get the most instrumental genre

# %%
# Group the dataset by genre and calculate the mean instrumentalness for each genre
genre_instrumentalness = df.groupby('genre')['instrumentalness'].mean()

# Find the genre with the highest average instrumentalness
most_instrumental_genre = genre_instrumentalness.idxmax()
highest_instrumentalness_score = genre_instrumentalness.max()
# Print result
print(f"The most instrumental genre is '{most_instrumental_genre}' with an average instrumentalness score of {highest_instrumentalness_score:.2f}")
# Out:
# The most instrumental genre is 'minimal-techno' with an average instrumentalness score of 0.80

# %% [markdown]
# # Print the most danceable song

# %%
# Sort the dataset by danceability in descending order
most_danceable_song = df.sort_values(by='danceability', ascending=False).iloc[0]

# Extract relevant information from the most danceable song
artist_name = most_danceable_song['artist_name']
track_name = most_danceable_song['track_name']
danceability = most_danceable_song['danceability']
# Print the most danceable song
print(f"The most danceable song is '{track_name}' by {artist_name} with a danceability score of {danceability:.4f}")
# Out:
# The most danceable song is 'Roll Like Dis / Cha-cha Slide Part 2' by Mr. C with a danceability score of 0.9930

# %% [markdown]
# # The most popular artists from 2012-2015

# %%
# Filter the dataset for years 2012 to 2015
filtered_dataset = df[(df['year'] >= 2012) & (df['year'] <= 2015)]

#  Group by artist and calculate average popularity during 2012-2015
artist_popularity = filtered_dataset.groupby('artist_name')['popularity'].mean()

# Sort artists by average popularity in descending order
sorted_artists = artist_popularity.sort_values(ascending=False)

# Select the top 10 most popular artists to plot
top_n = 10  
top_artists = sorted_artists.head(top_n)

# Create a bar chart for the most popular artists during 2012-2015
plt.figure(figsize=(12, 6))
plt.bar(top_artists.index, top_artists.values, color='purple')
plt.title(f'Top {top_n} Most Popular Artists (2012-2015)')
plt.xlabel('Artist')
plt.ylabel('Average Popularity')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# # Relationship between energy and loudness
# ## Create a scatter plot that visually represents the relationship between two variables energy and loudness
# - [Scatter](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html) - Reference for scatter graphs

# %%
# Scatter graph of energy and loudness
plt.scatter(df['energy'], df['loudness'])
plt.title('Energy vs. Loudness')
plt.xlabel('Energy')
plt.ylabel('Loudness')
plt.show()

# %% [markdown]
# # Show more relationships between these features
# ## Display histograms for four selected numeric features popularity, year, danceability, and energy

# %%
# Create subplots for histograms
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 8))
plt.subplots_adjust(hspace=0.4)

# Create histograms for the features
df['popularity'].plot(kind='hist', ax=axes[0, 0], bins=10, title='Popularity')
df['year'].plot(kind='hist', ax=axes[0, 1], bins=10, title='Year')
df['danceability'].plot(kind='hist', ax=axes[1, 0], bins=10, title='Danceability')
df['energy'].plot(kind='hist', ax=axes[1, 1], bins=10, title='Energy')

# Add labels
for ax in axes.flat:
    ax.set_xlabel('Value')
    ax.set_ylabel('Frequency')
plt.show()

# %% [markdown]
# # Visualise the trend
# ## Creates a line plot with two lines to visualize the trends over the years for two different features energy and danceability

# %%
# Line chart of energy and danceability
plt.figure(figsize=(10, 6))
df.groupby('year')['energy'].mean().plot(label='Average Energy')
df.groupby('year')['danceability'].mean().plot(label='Average Danceability')
plt.title('Trends Over Years')
plt.xlabel('Year')
plt.ylabel('Average Values')
plt.legend()
plt.show()

# %% [markdown]
# # Show the different genres in the dataset

# %%
genre_counts = df['genre'].value_counts()
plt.figure(figsize=(10, 6))
ax = genre_counts.plot(kind='bar', color='skyblue')

plt.title('Counts of Different Genres')
plt.xlabel('Genres')
plt.ylabel('Counts')

# Rotate x axis labels
ax.set_xticklabels(genre_counts.index, rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# #  Visualise the distribution of popularity
# # Create a histogram to view the data

# %%
# Histograms for features
plt.figure(figsize=(8, 6))
plt.hist(df['popularity'], bins=20, color='salmon', alpha=0.7)
plt.title('Distribution of Popularity')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualise the distribution of the energy column

# %%
# Box plot f
plt.boxplot(df['energy'], vert=False)
plt.title('Box Plot of Energy')
plt.xlabel('Energy')
plt.show()

# %% [markdown]
# # Visualise the relationship between danceability and energy

# %%
# Danceability scatter graph
plt.figure(figsize=(8, 6))
plt.scatter(df['danceability'], df['energy'], color='green', alpha=0.5)
plt.title('Danceability vs Energy')
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Visualise the popularity trend over the years

# %%
# Line chart for popularity  over the years
yearly_popularity = df.groupby('year')['popularity'].mean()
plt.figure(figsize=(10, 6))
yearly_popularity.plot(kind='line', marker='o', color='blue')
plt.title('Popularity Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Average Popularity')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Boxplots for the feature which did not lead to anything

# %%
plt.figure(figsize=(10, 6))

# Create a boxplot
boxprops = dict(linewidth=1)  
whiskerprops = dict(linewidth=1)  

boxplot = df.boxplot(column='acousticness', by='genre', vert=False, figsize=(10, 8),
                     boxprops=boxprops, whiskerprops=whiskerprops)
plt.yticks(rotation=20)
plt.title('Distribution of Acousticness by Genre')
plt.xlabel('Acousticness')
plt.ylabel('Genre')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Plots histograms for popularity, year and danceability

# %%
# Histogram for popularity
plt.figure(figsize=(8, 6))
plt.hist(df['popularity'], bins=20, color='skyblue', alpha=0.7)
plt.title('Popularity Distribution')
plt.xlabel('Popularity')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Histogram for year
plt.figure(figsize=(8, 6))
plt.hist(df['year'], bins=20, color='salmon', alpha=0.7)
plt.title('Year Distribution')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Histogram for danceability
plt.figure(figsize=(8, 6))
plt.hist(df['danceability'], bins=20, color='lightgreen', alpha=0.7)
plt.title('Danceability Distribution')
plt.xlabel('Danceability')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Find the distribution of Danceability results

# %%
# Box plot for danceability
plt.figure(figsize=(8, 6))
plt.boxplot(df['danceability'], vert=False)
plt.title('Box Plot of Danceability')
plt.xlabel('Danceability')
plt.show()

# %% [markdown]
# # Distributions of loudness, energy and valence
# ## Features that are closely related to danceability

# %%
df[['loudness', 'energy', 'valence']].hist(bins=15, figsize=(10, 7))
plt.suptitle('Distribution of Loudness, Energy, and Valence')
plt.show()

# %% [markdown]
# # Distribution of instrumentalness which did not lead to any conclusions

# %%
column_name = 'instrumentalness'

# Plotting a histogram for the selected column
plt.figure(figsize=(8, 6))
plt.hist(df[column_name], bins=30, color='skyblue', edgecolor='black')
plt.title('Histogram of ' + column_name)
plt.xlabel(column_name)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Visualise energy over the years

# %%
# Line chart for energy over the years
plt.figure(figsize=(10, 6))
df.groupby('year')['energy'].mean().plot()
plt.title('Average Energy Over Years')
plt.xlabel('Year')
plt.ylabel('Average Energy')
plt.show()

# %% [markdown]
# # Scatter chart for Danceability and Valence

# %%
# Scatter chart Danceability and Valence
plt.figure(figsize=(8, 6))
plt.scatter(df['danceability'], df['valence'], color='green', alpha=0.5)
plt.title('Danceability vs Valence')
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.grid(True, linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
